# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import missingno as msno
import os
import sys

# %%
arr = np.load('eda_df.npy', allow_pickle=True)
arr_headers = np.load('headers(eda_df).npy', allow_pickle=True)
df = pd.DataFrame(arr, columns = arr_headers)

# %%
df.describe()
df.info()
df.isna().sum()
msno.bar(df)
msno.matrix(df)
msno.heatmap(df)
msno.dendrogram(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371732 entries, 0 to 371731
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Date                      371732 non-null  object
#  1   TypeFact                  371732 non-null  object
#  2   TypeStock                 371732 non-null  object
#  3   Count                     186540 non-null  object
#  4   AmountEur                 183423 non-null  object
#  5   AmountWithVAT             183423 non-null  object
#  6   AmountCost                185432 non-null  object
#  7   AmountCostRub             184844 non-null  object
#  8   AmountPurchasePriceEur    184509 non-null  object
#  9   AmountNetPriceEur         184455 non-null  object
#  10  TypePrice                 371732 non-null  object
#  11  AmountBaseEur             180523 non-null  object
#  12  AmountBaseRub             180523 non-null  object
# ...
